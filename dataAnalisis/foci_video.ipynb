# %%
import tifffile
import os

stack = tifffile.imread("./Spatiotemporal metabolism in Streptomyces/FOCI Dynamics - every 30 s/GFP-8bit.tif")  # shape: (41, 393, 468, 3)
os.makedirs("frames", exist_ok=True)
for i, frame in enumerate(stack):
    tifffile.imwrite(f"frames/frame_{i:03d}.tif", frame)
